# %%
import sklearn
import pandas as pd
import random
from sklearn import datasets
data = pd.read_csv('mushroom.tsv', sep='\t')

# %% [markdown]
# ## K-fold cross validation

# %%
K = 5
number_of_entries = data.shape[0]
number_of_entries_edible = data[data['target'] == 0].shape[0]
number_of_entries_poisonous = data[data['target'] == 1].shape[0]

estrat = number_of_entries_poisonous / number_of_entries

instancias_por_fold = number_of_entries / K
instancias_por_fold_poison = number_of_entries_poisonous / K
instancias_por_fold_edible = number_of_entries_edible / K

fold_dataframes = {}

for i in range(1,K-1):
    fold_df_poison = data[data['target'] == 1].sample(frac=0.005)
    fold_df_edible = data[data['target'] == 0].sample(frac=0.005)
    new_df_2 = new_df.sample(n=11)
    new_df = new_df.drop(new_df_2.index)

# %%
number_of_entries_poisonous
# Out:
# 3916

# %%
number_of_entries / K
# Out:
# 1624.8

# %%
[number_of_entries, number_of_entries_edible, number_of_entries_poisonous]
# Out:
# [8124, 4208, 3916]

# %% [markdown]
# ## Testing basic functionalities of Python, SKLearn and Pandas

# %%
data
# Out:
#       cap-shape  cap-surface  cap-color  bruises?  odor  gill-attachment  \
# 0             2            0          7         0     6                1
# 1             0            3          9         0     0                1
# 2             2            3          8         1     6                1
# 3             2            2          3         1     4                1
# 4             3            0          0         0     6                1
# ...         ...          ...        ...       ...   ...              ...
# 8119          3            2          0         1     8                1
# 8120          3            2          8         0     7                1
# 8121          2            0          8         1     6                1
# 8122          2            3          8         1     6                1
# 8123          3            2          0         1     3                1
#
#       gill-spacing  gill-size  gill-color  stalk-shape  ...  \
# 0                0          0           8            1  ...
# 1                0          0           4            0  ...
# 2                1          0           0            1  ...
# 3                0          0           4            0  ...
# 4                0          0           8            1  ...
# ...            ...        ...         ...          ...  ...
# 8119             0          1           2            1  ...
# 8120             0          1           0            0  ...
# 8121             1          0           4            0  ...
# 8122             1          0           4            0  ...
# 8123             0          1           2            1  ...
#
#       stalk-color-above-ring  stalk-color-below-ring  veil-type  veil-color  \
# 0                          3                       5          0           2
# 1                          7                       7          0           2
# 2                          7                       7          0           2
# 3                          0                       5          0           2
# 4                          7                       5          0           2
# ...                      ...                     ...        ...         ...
# 8119                       5                       7          0           2
# 8120                       7                       7          0           2
# 8121                       7                       7          0           2
# 8122                       7                       7          0           2
# 8123                       7                       5          0           2
#
#       ring-number  ring-type  spore-print-color  population  habitat  target
# 0               1          4                  1           4        6       0
# 1               1          4                  0           2        0       0
# 2               1          0                  0           3        0       0
# 3               1          2                  3           4        3       1
# 4               1          4                  0           5        6       0
# ...           ...        ...                ...         ...      ...     ...
# 8119            1          0                  7           4        1       1
# 8120            1          4                  0           3        4       1
# 8121            2          4                  7           2        0       0
# 8122            2          4                  7           3        0       0
# 8123            1          0                  7           4        6       1
#
# [8124 rows x 23 columns]

# %%
data.sample(10).target
# Out:
# 2950    0
# 4817    1
# 6910    0
# 2580    0
# 6968    0
# 7251    1
# 6071    1
# 6680    1
# 430     1
# 4449    0
# Name: target, dtype: int64

# %%
new_df = data[data['target'] == 0].sample(frac=0.005)

# %%
new_df = data[data['target'] == 0].sample(frac=0.005)
new_df_2 = new_df.sample(n=11)
new_df = new_df.drop(new_df_2.index)

# %%
new_df_2.shape[0]
# Out:
# 11

# %%
new_df_2
# Out:
#       cap-shape  cap-surface  cap-color  bruises?  odor  gill-attachment  \
# 1725          2            2          9         0     0                1
# 3705          2            2          7         0     6                1
# 7180          2            2          8         0     1                1
# 624           2            2          0         0     6                1
# 840           2            3          8         0     1                1
# 1398          2            2          0         0     6                1
# 6412          3            2          0         0     1                1
# 7367          0            3          9         0     1                1
# 3840          0            3          8         0     0                1
# 186           4            0          3         1     6                1
# 1387          2            3          0         1     6                0
#
#       gill-spacing  gill-size  gill-color  stalk-shape  ...  \
# 1725             0          0           4            0  ...
# 3705             0          0          10            1  ...
# 7180             0          0           4            0  ...
# 624              0          0           8            1  ...
# 840              0          0           4            0  ...
# 1398             0          0           8            1  ...
# 6412             0          0          10            0  ...
# 7367             0          0           0            0  ...
# 3840             0          0           4            0  ...
# 186              1          0          10            0  ...
# 1387             0          0           6            0  ...
#
#       stalk-color-above-ring  stalk-color-below-ring  veil-type  veil-color  \
# 1725                       7                       7          0           2
# 3705                       5                       3          0           2
# 7180                       7                       7          0           2
# 624                        7                       5          0           2
# 840                        7                       7          0           2
# 1398                       3                       5          0           2
# 6412                       7                       7          0           2
# 7367                       7                       7          0           2
# 3840                       7                       7          0           2
# 186                        7                       7          0           2
# 1387                       4                       4          0           0
#
#       ring-number  ring-type  spore-print-color  population  habitat  target
# 1725            1          4                  0           2        2       0
# 3705            1          4                  0           5        6       0
# 7180            1          4                  0           2        0       0
# 624             1          4                  0           4        6       0
# 840             1          4                  0           3        0       0
# 1398            1          4                  1           4        6       0
# 6412            1          4                  1           3        3       0
# 7367            1          4                  1           2        2       0
# 3840            1          4                  1           2        0       0
# 186             2          4                  7           2        0       0
# 1387            1          4                  2           1        1       0
#
# [11 rows x 23 columns]
